# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab
#
# ## Introduction
#
# In this lab, let's get some hands on practice working with data cleanup using Pandas.
#
# ## Objectives
# You will be able to:
#
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes
#
# ## Let's get started!

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('turnstile_180901.txt')
print(len(df))
df.head()
# Out:
# 197625
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# ## Rename all the columns to lower case

# %%
#Your code here
df.columns = [x.lower() for x in df.columns]
df.head()
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# ## Change the Index to be the Line Names

# %%
#Your code here
df = df.set_index('linename')
df.head()
# Out:
#            c/a  unit       scp station division        date      time  \
# linename
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#              desc  entries  \
# linename
# NQR456W   REGULAR  6736067
# NQR456W   REGULAR  6736087
# NQR456W   REGULAR  6736105
# NQR456W   REGULAR  6736180
# NQR456W   REGULAR  6736349
#
#           exits
# linename
# NQR456W                                             2283184
# NQR456W                                             2283188
# NQR456W                                             2283229
# NQR456W                                             2283314
# NQR456W                                             2283384

# %% [markdown]
# # Change the index back

# %%
# Your code here
df = df.reset_index()
df.head()
# Out:
#   linename   c/a  unit       scp station division        date      time  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# 2  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# 3  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# 4  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# ## Create another column 'Num_Lines' that is a count of how many lines pass through a station. Then sort your dataframe by this column in descending order

# %%
# Your code here
#df['Num_Lines'] = df.linename.map(lambda x: len(x))
df['Num_Lines'] = [len(i) for i in df.linename]
df.sort_values(by=['Num_Lines'])
# Out:
#             linename    c/a  unit       scp          station division  \
# 98812              F   N528  R257  01-06-01    EAST BROADWAY      IND
# 116031             1  PTH12  R542  00-04-01  TWENTY THIRD ST      PTH
# 116030             1  PTH12  R542  00-04-01  TWENTY THIRD ST      PTH
# 116029             1  PTH12  R542  00-04-01  TWENTY THIRD ST      PTH
# 116028             1  PTH12  R542  00-04-01  TWENTY THIRD ST      PTH
# 116027             1  PTH12  R542  00-04-01  TWENTY THIRD ST      PTH
# 116026             1  PTH12  R542  00-04-01  TWENTY THIRD ST      PTH
# 116025             1  PTH12  R542  00-04-01  TWENTY THIRD ST      PTH
# 116024             1  PTH12  R542  00-04-01  TWENTY THIRD ST      PTH
# 116023             1  PTH12  R542  00-04-01  TWENTY THIRD ST      PTH
# 116022             1  PTH12  R542  00-04-00  TWENTY THIRD ST      PTH
# 116021             1  PTH12  R542  00-04-00  TWENTY THIRD ST      PTH
# ...

# %% [markdown]
# ## Write a function to clean a column name

# %%
def clean(col_name):
    cleaned = col_name.title()
    #Your code here; whatever you want to do to col_name. Hint: think back to str methods.
    return cleaned

# %%
#This is a list comprehension. It applies your clean function to every item in the list.
#We then reassign that to df.columns
#You shouldn't have to change anything here.
#Your function above should work appropriately here.
df.columns = [clean(col) for col in df.columns]

# %%
#Checking the output, we can see the results.
df.columns
# Out:
# Index(['Linename', 'C/A', 'Unit', 'Scp', 'Station', 'Division', 'Date', 'Time',
#        'Desc', 'Entries',
#        'Exits                                                               ',
#        'Num_Lines'],
#       dtype='object')

# %% [markdown]
# ## Group the Data by Day of Week and Plot the Sum of The Numeric Columns

# %%
#Your code here

df.Date = pd.to_datetime(df.Date)
df['Week_day'] = df.Date.dt.dayofweek
grouped = df.groupby(df.Week_day).sum()
grouped.plot(kind='bar')

# %% [markdown]
# ## Group the Data by Weekend/Weekday and Plot the Sum of the Numeric Columns

# %%
#Your code here
df['Weekend'] = df['Week_day'].map(lambda x: x in [5,6])
weekend_grouped = df.groupby(df.Weekend).sum()
weekend_grouped.info()
weekend_grouped.plot(kind='bar')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, False to True
# Data columns (total 4 columns):
# Entries                                                                 2 non-null int64
# Exits                                                                   2 non-null int64
# Num_Lines                                                               2 non-null int64
# Week_day                                                                2 non-null int64
# dtypes: int64(4)
# memory usage: 80.0+ bytes

# %% [markdown]
# ## Analysis Question:
#
# What is misleading about the day of week and weekend/weekday charts you just plotted?

# %%
# Your answer here

# %% [markdown]
# ## Drop a couple of columns

# %%
# Your code here
df = df.drop('Time', axis=1)
df.head()
# Out:
#   Linename   C/A  Unit       Scp Station Division       Date  Entries  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  6736067
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  6736087
# 2  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  6736105
# 3  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  6736180
# 4  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  6736349
#
#    Exits                                                                 \
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384
#
#    Num_Lines  Week_day  Weekend
# 0          7         5     True
# 1          7         5     True
# 2          7         5     True
# 3          7         5     True
# 4          7         5     True

# %% [markdown]
# ## Summary
#
# Great! You practiced your data cleanup-skills using Pandas.
